# %% [markdown]
# Complete speech-based math expression recognizer and evaluator using Google Text-to-Speech (gTTS) and Google Speech Recognition

# %%
# !pip install gtts

from gtts import gTTS

text ="5+5"

lang ="en"
res = gTTS(text=text,lang=lang,slow=False)

res.save("ta.mp3")

# Step 1: Install required libraries (run in a notebook or script)
# !pip install SpeechRecognition pydub gTTS


# Step 2: Import libraries
import speech_recognition as sr
from pydub import AudioSegment
from gtts import gTTS
import re


# Step 3: Convert MP3 to WAV (SpeechRecognition needs WAV)
mp3_file = r'/content/ta.mp3'
audio = AudioSegment.from_file(mp3_file)
audio.export("temp.wav", format="wav")


# Step 4: Transcribe audio
recognizer = sr.Recognizer()
with sr.AudioFile("temp.wav") as source:
    audio_data = recognizer.record(source)
    text = recognizer.recognize_google(audio_data)

print("Recognized text:", text)


# Step 5: Detect and evaluate math expression like "5 + 5"
expression_match = re.search(r'(\d+)\s*[\+\-\*/]\s*(\d+)', text)
if expression_match:
    expression = expression_match.group(0)
    try:
        result = eval(expression)
        answer_text = f"The answer is {result}"
    except Exception as e:
        answer_text = "Sorry, I could not evaluate that expression"
else:
    answer_text = "No valid math expression found"

print("Answer:", answer_text)


# Step 6: Convert the answer to speech and save it
tts = gTTS(answer_text)
tts.save("/content/answer.mp3")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 17.2 MB/s eta 0:00:00
# ...
# Recognized text: 5 + 5
# Answer: The answer is 10

# %% [markdown]
# TEXT CLASSIFICATION

# %%
pip install transformers

# %%
from transformers import pipeline

# %%
analyzer = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# ...

# %%
text_input = input('enter some text:')
# Out:
# enter some text:The movie was interesting, but it dragged on for too long.

# %%
result=analyzer(text_input)

# %%
result
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9992215633392334}]

# %% [markdown]
# TEXT GENERATOR

# %%
generate = pipeline('text-generation')
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...

# %%
statement = input('enter any short statement: ')
# Out:
# enter any short statement: Hence by the principle of

# %%
result = generate(statement,max_length = 150)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
result
# Out:
# [{'generated_text': 'Hence by the principle of reciprocity of the means of production. On the other hand it is possible to produce a piece of metal, a piece of brass or brass with certain qualities of an object, an object which is made of certain metals. For a few reasons this cannot be done. First, as has been noted, the objects which may make a certain piece of metal are also known to be of different qualities. Hence there may be an object which can be made out of a piece of silver, a piece of copper, etc., but so as to be of different qualities; for a piece of steel, however, in which all metals are considered, cannot be made of silver, but rather of copper. Thus when a single piece of'}]

# %% [markdown]
# NAMED ENTITY RECOGNITION (NER)

# %%
named_entity_recognition = pipeline('ner')
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# ...

# %%
text = input('enter a statement')
# Out:
# enter a statementVFSTR is university located in Vadlamudi , Guntur

# %%
result = named_entity_recognition(text)

# %%
result
# Out:
# [{'entity': 'I-ORG',
#   'score': np.float32(0.99516934),
#   'index': 1,
#   'word': 'V',
#   'start': 0,
#   'end': 1},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.99703026),
#   'index': 2,
#   'word': '##FS',
#   'start': 1,
#   'end': 3},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9919938),
#   'index': 3,
#   'word': '##TR',
#   'start': 3,
#   'end': 5},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.9895914),
#   'index': 8,
#   'word': 'V',
#   'start': 31,
#   'end': 32},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.9751159),
#   'index': 9,
#   'word': '##ad',
#   'start': 32,
#   'end': 34},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.89377666),
#   'index': 10,
#   'word': '##lam',
#   'start': 34,
#   'end': 37},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.97068495),
#   'index': 11,
#   'word': '##udi',
#   'start': 37,
#   'end': 40},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.98981327),
#   'index': 13,
#   'word': 'Gun',
# ...

# %% [markdown]
# QUESTION - ANSWER

# %%
q_a = pipeline('question-answering')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
result = q_a({
    'question': 'What is the use of this story?',
    'context': """

---

## 🌲 **"The Whispering Forest"**

Once upon a time, in a quiet village nestled at the edge of an ancient forest, lived a curious 14-year-old girl named Elara. Her dark, wild curls and bright eyes made her stand out among the townsfolk, but what truly made her unique was her unquenchable thirst for stories — especially those buried in forgotten pages and hidden places.

Every villager feared the forest. Old tales warned of spirits that whispered your name, leading you deeper into the woods until you vanished forever. But Elara? She found it all thrilling.

One crisp autumn morning, while helping her grandfather clean out the attic, she discovered a weathered journal with a brass clasp. Its cover bore a name she recognized only from hushed village gossip: **“Aurelius Thorne”** — a historian who had disappeared in the forest over 50 years ago.

Inside the journal were notes, maps, and entries that hinted at an ancient secret hidden beneath the forest floor — **“The Heart of Whispers.”** According to Aurelius, this “Heart” was not just a myth but something very real — a relic said to hold the voices and wisdom of the forest itself.

That night, Elara couldn’t sleep. Her window faced the woods, and the moonlight painted the trees silver. Something called to her — not in a loud voice, but like a gentle nudge from an old friend. She packed a satchel with her grandfather’s compass, a flashlight, some bread, and the journal. Then, without a sound, she stepped into the shadows of the forest.

---
"""
})

# %%
result
# Out:
# {'score': 0.22844232618808746,
#  'start': 278,
#  'end': 313,
#  'answer': 'her unquenchable thirst for stories'}

# %% [markdown]
# WHILE TRUE LOOP FOR ANSWERING MULTIPLE QUESTIONS

# %%
from transformers import pipeline

# Load the question-answering pipeline
q_a = pipeline("question-answering")

# Define the story context
context = """
## 🌲 **"The Whispering Forest"**

Once upon a time, in a quiet village nestled at the edge of an ancient forest, lived a curious 14-year-old girl named Elara. Her dark, wild curls and bright eyes made her stand out among the townsfolk, but what truly made her unique was her unquenchable thirst for stories — especially those buried in forgotten pages and hidden places.

Every villager feared the forest. Old tales warned of spirits that whispered your name, leading you deeper into the woods until you vanished forever. But Elara? She found it all thrilling.

One crisp autumn morning, while helping her grandfather clean out the attic, she discovered a weathered journal with a brass clasp. Its cover bore a name she recognized only from hushed village gossip: **“Aurelius Thorne”** — a historian who had disappeared in the forest over 50 years ago.

Inside the journal were notes, maps, and entries that hinted at an ancient secret hidden beneath the forest floor — **“The Heart of Whispers.”** According to Aurelius, this “Heart” was not just a myth but something very real — a relic said to hold the voices and wisdom of the forest itself.

That night, Elara couldn’t sleep. Her window faced the woods, and the moonlight painted the trees silver. Something called to her — not in a loud voice, but like a gentle nudge from an old friend. She packed a satchel with her grandfather’s compass, a flashlight, some bread, and the journal. Then, without a sound, she stepped into the shadows of the forest.
"""

# Loop to take multiple questions
while True:
    question = input("\nEnter your question (or type 'exit' to quit): ")

    if question.lower() == 'exit':
        print("Exiting the Q&A session.")
        break

    result = q_a({
        'question': question,
        'context': context
    })

    print("Answer:", result['answer'])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Enter your question (or type 'exit' to quit): What is the story about?
# Answer: The Whispering Forest
#
# Enter your question (or type 'exit' to quit): What can we learn from the story?
# Answer: her unquenchable thirst for stories
#
# Enter your question (or type 'exit' to quit): Who are the main characters?
# Answer: Elara
#
# Enter your question (or type 'exit' to quit): quit
# Answer: she stepped into the shadows of the forest.
#
# Enter your question (or type 'exit' to quit): exit
# Exiting the Q&A session.

# %% [markdown]
# SUMMARIZATION

# %%
summarize = pipeline('summarization')
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
text = input('')
# Out:
#  ## 🌲 **"The Whispering Forest"**  Once upon a time, in a quiet village nestled at the edge of an ancient forest, lived a curious 14-year-old girl named Elara. Her dark, wild curls and bright eyes made her stand out among the townsfolk, but what truly made her unique was her unquenchable thirst for stories — especially those buried in forgotten pages and hidden places.  Every villager feared the forest. Old tales warned of spirits that whispered your name, leading you deeper into the woods until you vanished forever. But Elara? She found it all thrilling.  One crisp autumn morning, while helping her grandfather clean out the attic, she discovered a weathered journal with a brass clasp. Its cover bore a name she recognized only from hushed village gossip: **“Aurelius Thorne”** — a historian who had disappeared in the forest over 50 years ago.  Inside the journal were notes, maps, and entries that hinted at an ancient secret hidden beneath the forest floor — **“The Heart of Whispers.”*
# ...

# %%
result = summarize(text,max_length = 50)
# Out:
# Your min_length=56 must be inferior than your max_length=50.
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py:1570: UserWarning: Unfeasible length constraints: `min_length` (56) is larger than the maximum possible length (50). Generation will stop at the defined maximum length. You should decrease the minimum length and/or increase the maximum length.
#   warnings.warn(

# %%
result
# Out:
# [{'summary_text': ' Elara, a 14-year-old girl from a quiet village in an ancient forest, discovered a weathered journal with a brass clasp . The journal belonged to a historian who had disappeared in the forest over 50 years ago . Aure'}]

# %% [markdown]
# WHILE TRUE LOOP FOR SUMMARIZING MANY TEXTS

# %%
from transformers import pipeline

# Load the summarization pipeline
summarize = pipeline('summarization')

print("Enter text to summarize (type 'exit' to stop):")

while True:
    # Take input from the user
    text = input("\nYour input: ")

    # Exit condition
    if text.lower() == 'exit':
        print("Exiting the summarizer.")
        break

    # Skip empty input
    if not text.strip():
        print("Please enter some text.")
        continue

    # Summarize and display the result
    try:
        result = summarize(text, max_length=50, min_length=10, do_sample=False)
        print("Summary:", result[0]['summary_text'])
    except Exception as e:
        print("Error summarizing:", e)
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Enter text to summarize (type 'exit' to stop):
#
# ...

# %% [markdown]
# TRANSLATOR

# %%
from transformers import pipeline

# %%
translator = pipeline('translation_en_to_fr')
# Out:
# No model was supplied, defaulted to google-t5/t5-base and revision a9723ea (https://huggingface.co/google-t5/t5-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
text = input('enter some text')
# Out:
# enter some textHello! How are you?

# %%
res = translator(text)

# %%
res
# Out:
# [{'translation_text': 'Bonjour, comment êtes-vous?'}]

# %% [markdown]
# FILL MASK

# %%
f_m = pipeline('fill-mask')
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# ...

# %%
text = input('enter a statement with a black having <mask>:')
# Out:
# enter a statement with a black having <mask>:I <mask> Studying

# %%
res = f_m(text)

# %%
res
# Out:
# [{'score': 0.41523662209510803,
#   'token': 27032,
#   'token_str': ' Hate',
#   'sequence': 'I Hate Studying'},
#  {'score': 0.12427055090665817,
#   'token': 1918,
#   'token_str': ' Am',
#   'sequence': 'I Am Studying'},
#  {'score': 0.08176829665899277,
#   'token': 3437,
#   'token_str': ' Love',
#   'sequence': 'I Love Studying'},
#  {'score': 0.07981466501951218,
#   'token': 437,
#   'token_str': "'m",
#   'sequence': "I'm Studying"},
#  {'score': 0.05527408421039581,
#   'token': 41990,
#   'token_str': ' Quit',
#   'sequence': 'I Quit Studying'}]

# %% [markdown]
# FEATURE EXTRACTION

# %%
features=pipeline('feature-extraction')
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased and revision 6ea8117 (https://huggingface.co/distilbert/distilbert-base-cased).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/465 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/263M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# ...

# %%
text = input("Enter your text: ")
# Out:
# Enter your text: 'Dream big, hustle harder, and let your vibe rewrite the rules.'

# %%
res = features(text)

# %%
res
# Out:
# [[[0.25612685084342957,
#    0.04890916123986244,
#    -0.04798978567123413,
#    -0.124636709690094,
#    -0.29089125990867615,
#    -0.07662215828895569,
#    0.28584593534469604,
#    -0.16472655534744263,
#    0.1198902353644371,
#    -1.0596764087677002,
#    -0.304399311542511,
#    0.025773432105779648,
#    -0.15747053921222687,
#    -0.054181259125471115,
#    -0.3628499507904053,
#    0.11706432700157166,
#    0.1418820321559906,
#    0.047625958919525146,
#    -0.19104821979999542,
#    -0.2068154364824295,
#    0.14631140232086182,
#    -0.2487439662218094,
#    0.5062878727912903,
#    -0.28659963607788086,
#    0.2783257067203522,
#    0.06921788305044174,
#    0.12076877057552338,
#    0.07440247386693954,
#    -0.23974096775054932,
#    0.406652569770813,
#    0.06842809170484543,
#    0.29888448119163513,
#    -0.15316246449947357,
#    -0.053586363792419434,
#    -0.16014762222766876,
#    0.13331753015518188,
#    0.03791243955492973,
#    -0.2171487808227539,
# ...

# %% [markdown]
# INTERACTIVE CHATBOT

# %%
from transformers import pipeline

# %%
chatbot = pipeline('text-generation')
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# ...

# %%
while True:
  text = input('You: ')
  if text.lower()=='quit':
    break
  res = chatbot(text)
  print('Chatbot: ',res[0]['generated_text'])
# Out:
# You: Helloo!!
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot:  Helloo!! [01:22:50] [Client thread/INFO] [mcjty.varia.Logging]: Registering texture [durkinstechworks.common/world/Item/Item.ItemTemplate.Item
# You: Are you familiar with term Alitame?
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Chatbot:  Are you familiar with term Alitame?
#
# The best-selling, most highly respected and most popular term from Japan is Alitame. This is a Japanese word that means "love."
#
# A word Alitame (also abbrevi
# You: quit

# %% [markdown]
# VISUAL QUESTION ANSWERING

# %%
image_que=pipeline('visual-question-answering')
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision d0a1f6a (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/136k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/470M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/470M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/320 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/251 [00:00<?, ?B/s]
# ...

# %%
image='/content/dog.jpg'

# %%
question=input('enter question')
result=image_que(image,question)
print (result)
# Out:
# enter questionwhat is depicted in the picture?
# [{'score': 0.9623687863349915, 'answer': 'dog'}, {'score': 0.030277904123067856, 'answer': 'golden retriever'}, {'score': 0.029096223413944244, 'answer': 'lab'}, {'score': 0.010451476089656353, 'answer': 'puppy'}, {'score': 0.008948592469096184, 'answer': 'dogs'}]
